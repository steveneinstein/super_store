# %%
import pandas as pd

# %%
df = pd.read_excel('Superstore_USA.xlsx')

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
for i in df:
    print(i)
# Out:
# Row ID
# Order Priority
# Discount
# Unit Price
# Shipping Cost
# Customer ID
# Customer Name
# Ship Mode
# Customer Segment
# Product Category
# Product Sub-Category
# Product Container
# Product Name
# Product Base Margin
# Region
# State or Province
# City
# Postal Code
# Order Date
# Ship Date
# Profit
# Quantity ordered new
# Sales
# Order ID

# %% [markdown]
# # 3 . Find out how return that we ahve recived and with a product id

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df.groupby(['Order ID']).sum()[['Profit']]
# Out:
#              Profit
# Order ID
# 6           -4.6400
# 193        -37.0400
# 322        -33.8300
# 358      -1078.7900
# 359       -500.3800
# ...             ...
# 91587      134.9088
# 91588       -8.1100
# 91589       23.4980
# 91590     -177.6260
# 91591     2120.5591
#
# [6455 rows x 1 columns]

# %% [markdown]
# # 4 . try  to join order and return data both in sql and pandas

# %% [markdown]
# # 5 . Try to find out how many unique customer that we have

# %%
len(df['Customer Name'].unique())
# Out:
# 2703

# %%
df['Customer Name'].nunique()
# Out:
# 2703

# %% [markdown]
# # 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
#
#   Profit  Quantity ordered new  Sales Order ID
# ...

# %%
len(df.groupby(['Region']).count()[[]])
# Out:
# 4

# %%
df.groupby(['Region']).count()[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [Central, East, South, West]

# %%
df.groupby(['Region']).count()
# Out:
#          Row ID  Order Priority  Discount  Unit Price  Shipping Cost  \
# Region
# Central    2899            2899      2899        2899           2899
# East       2289            2289      2289        2289           2289
# South      1954            1954      1954        1954           1954
# West       2284            2284      2284        2284           2284
#
#          Customer ID  Customer Name  Ship Mode  Customer Segment  \
# Region
# Central         2899           2899       2899              2899
# East            2289           2289       2289              2289
# South           1954           1954       1954              1954
# West            2284           2284       2284              2284
#
#          Product Category  ...  State or Province  City  Postal Code  \
# Region                     ...
# Central              2899  ...               2899  2899         2899
# East                 2289  ...               2289  2289         2289
# ...

# %%
# Out:
# <bound method GroupBy.all of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001275E14ECD0>>

# %%
df.groupby(['Order ID']).count()[['Region']]
# Out:
#           Region
# Order ID
# 6              1
# 193            1
# 322            2
# 358            2
# 359            1
# ...          ...
# 91587          1
# 91588          1
# 91589          2
# 91590          2
# 91591          3
#
# [6455 rows x 1 columns]

# %%
df.groupby(['Region']).sum()[['Profit']].idxmax(),df.groupby(['Region']).sum()[['Profit']].max()
# Out:
# (Profit    Central
#  dtype: object,
#  Profit    519825.567067
#  dtype: float64)

# %%
df.groupby(['Region']).sum()[['Profit']].idxmin(),df.groupby(['Region']).sum()[['Profit']].min()
# Out:
# (Profit    South
#  dtype: object,
#  Profit    104201.19242
#  dtype: float64)

# %%
len(df['State or Province'].unique())
# Out:
# 49

# %%
df.groupby(['State or Province']).sum()[['Profit']].idxmax(),df.groupby(['State or Province']).sum()[['Profit']].max()
# Out:
# (Profit    Illinois
#  dtype: object,
#  Profit    127840.02301
#  dtype: float64)

# %% [markdown]
# # 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
 (df.groupby(['Ship Mode']).count()[['Order ID']]).sum()
# Out:
# Order ID    9426
# dtype: int64

# %%
 (df.groupby(['Ship Mode']).count()[['Order ID']])
# Out:
#                 Order ID
# Ship Mode
# Delivery Truck      1283
# Express Air         1107
# Regular Air         7036

# %%
((df.groupby(['Ship Mode']).count()[['Order ID']])/((df.groupby(['Ship Mode']).count()[['Order ID']]).sum()))*100
# Out:
#                  Order ID
# Ship Mode
# Delivery Truck  13.611288
# Express Air     11.744112
# Regular Air     74.644600

# %% [markdown]
# # 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format = '%Y-%m-%d')

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format = '%Y-%m-%d')

# %%
df['order_date - shipment date'] = df['Ship Date'] - df['Order Date']

# %%
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# # 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
df[(df['order_date - shipment date'].dt.days.astype('int16'))>10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %% [markdown]
# # 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
(df[(df['order_date - shipment date'].dt.days.astype('int16'))>15])[['order_date - shipment date','Order ID','Region']]
# Out:
#      order_date - shipment date  Order ID   Region
# 643                     84 days     87215  Central
# 1678                    17 days     87957     West
# 1680                    28 days     87957     West
# 1697                    17 days     19556     West
# 1699                    28 days     19556     West
# 2515                    92 days     86177     West
# 5673                    17 days     88352     East
# 5859                    22 days     87572    South
# 5881                    24 days     91294     West
# 8607                    18 days     86434    South
# 8609                    17 days     86436    South
# 8610                    19 days     86436    South
# 8973                    19 days     87300    South
# 8982                    27 days     19841     East
# 8983                    31 days     19841     East
# 8993                    19 days     19841     East
# 8996                    27 days     87300     East
# ...

# %%
df2
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# ...

# %%
df2[['order_date - shipment date','Order ID','Region']]
# Out:
#      order_date - shipment date  Order ID   Region
# 643                     84 days     87215  Central
# 1678                    17 days     87957     West
# 1680                    28 days     87957     West
# 1697                    17 days     19556     West
# 1699                    28 days     19556     West
# 2515                    92 days     86177     West
# 5673                    17 days     88352     East
# 5859                    22 days     87572    South
# 5881                    24 days     91294     West
# 8607                    18 days     86434    South
# 8609                    17 days     86436    South
# 8610                    19 days     86436    South
# 8973                    19 days     87300    South
# 8982                    27 days     19841     East
# 8983                    31 days     19841     East
# 8993                    19 days     19841     East
# 8996                    27 days     87300     East
# ...

# %% [markdown]
# # 11 . Gorup by region and find out which region is more profitable

# %%
df.groupby(['Region']).sum()[['Profit']].idxmax(),df.groupby(['Region']).sum()[['Profit']].max()
# Out:
# (Profit    Central
#  dtype: object,
#  Profit    519825.567067
#  dtype: float64)

# %% [markdown]
# # 12 . Try to find out overalll in which country we are giving more didscount

# %%
df.groupby(['State or Province']).sum()['Discount'].idxmax(),df.groupby(['State or Province']).sum()['Discount'].max()
# Out:
# ('California', 52.28)

# %% [markdown]
# # 13 . Give me a list of unique postal code

# %%
list(df['Postal Code'].unique())
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %% [markdown]
# # 14 . which customer segement is more profitalble find it out

# %%
df.groupby(['Customer Segment']).sum()[['Profit']].idxmax(),df.groupby(['Customer Segment']).sum()[['Profit']].max()
# Out:
# (Profit    Corporate
#  dtype: object,
#  Profit    505538.627783
#  dtype: float64)

# %% [markdown]
# # 15 . try to find out the 10th most loss making product catagory .

# %%
df3=(df[['Product Category','Profit','Product Name']])

# %%
df3
# Out:
#      Product Category       Profit  \
# 0     Office Supplies     1.320000
# 1     Office Supplies     4.560000
# 2     Office Supplies   -47.640000
# 3     Office Supplies   -30.510000
# 4          Technology   998.202300
# ...               ...          ...
# 9421  Office Supplies   137.860000
# 9422  Office Supplies   -39.070000
# 9423        Furniture -1225.029097
# 9424        Furniture   349.485000
# 9425  Office Supplies    78.062400
#
#                                            Product Name
# 0                                              Avery 49
# 1        SANFORD Liquid Accent™ Tank-Style Highlighters
# 2                                            Xerox 1968
# 3              Acme® Preferred Stainless Steel Scissors
# 4                                                   V70
# ...                                                 ...
# 9421      Jet-Pak Recycled Peel 'N' Seal Padded Mailers
# 9422       Eldon Spacemaker® Box, Quick-Snap Lid, Clear
# ...

# %%
(df[['Product Category','Profit','Product Name']]).nsmallest(10, ['Profit'])
# Out:
#      Product Category        Profit  \
# 4659       Technology -16476.838000
# 4338  Office Supplies -14369.123580
# 7800       Technology -14140.701600
# 4844        Furniture -13706.464000
# 5402       Technology -13562.637408
# 5409       Technology -10402.943916
# 7725       Technology -10263.659700
# 2191       Technology  -9078.940000
# 4068       Technology  -8570.448300
# 4857       Technology  -7961.430900
#
#                                            Product Name
# 4659                                               5165
# 4338                Large Capacity Hanging Post Binders
# 7800   Polycom ViewStation™ ISDN Videoconferencing Unit
# 4844  Riverside Palais Royal Lawyers Bookcase, Royal...
# 5402   Polycom ViewStation™ ISDN Videoconferencing Unit
# 5409  Okidata Pacemark 4410N Wide Format Dot Matrix ...
# 7725   Polycom ViewStation™ ISDN Videoconferencing Unit
# 2191              Canon imageCLASS 2200 Advanced Copier
# ...

# %% [markdown]
# # 16 . Try to find out 10 top  product with highest margins

# %%
df3=(df[['Product Category','Product Base Margin','Product Name']]).nlargest(10, ['Product Base Margin'])

# %%
df3
# Out:
#     Product Category  Product Base Margin  \
# 230  Office Supplies                 0.85
# 253       Technology                 0.85
# 262       Technology                 0.85
# 686  Office Supplies                 0.85
# 742       Technology                 0.85
# 807       Technology                 0.85
# 816       Technology                 0.85
# 881  Office Supplies                 0.85
# 963       Technology                 0.85
# 976       Technology                 0.85
#
#                                           Product Name
# 230                   Belkin OmniView SE Rackmount Kit
# 253                                        Accessory27
# 262                                        Accessory27
# 686  Office Impressions Heavy Duty Welded Shelving ...
# 742                                        Accessory27
# 807                                        Accessory27
# 816                                        Accessory27
# ...

# %%
((df[['Product Category','Product Base Margin','Product Sub-Category','Product Name']]).groupby(['Product Sub-Category']).first()).nlargest(10, ['Product Base Margin'])
# Out:
#                               Product Category  Product Base Margin  \
# Product Sub-Category
# Storage & Organization         Office Supplies                 0.80
# Tables                               Furniture                 0.78
# Bookcases                            Furniture                 0.77
# Computer Peripherals                Technology                 0.68
# Chairs & Chairmats                   Furniture                 0.60
# Telephones and Communication        Technology                 0.59
# Appliances                     Office Supplies                 0.56
# Scissors, Rulers and Trimmers  Office Supplies                 0.56
# Pens & Art Supplies            Office Supplies                 0.54
# Office Furnishings                   Furniture                 0.45
#
#                                                                     Product Name
# Product Sub-Category
# Storage & Organization                 Space Solutions Commercial Steel Shelving
# ...
